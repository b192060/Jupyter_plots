# %%
pwd
# Out:
# '/home/cse-lab/Desktop/b192060'

# %%
ls
# Out:
# b192060.ipynb  MELBOURNE_HOUSE_PRICES_LESS.csv

# %%
import pandas as pd

# %%
ab = pd.read_csv("MELBOURNE_HOUSE_PRICES_LESS.csv")

# %%
ab.tail(3)
# Out:
#                  Suburb         Address  Rooms Type     Price Method SellerG  \
# 63020     Roxburgh Park  5 Parkinson Wy      3    h  545000.0      S   Raine
# 63021        Thomastown  3/1 Travers St      3    u       NaN     PI   Barry
# 63022  Williams Landing     1 Diadem Wy      4    h       NaN     SP  Aussie
#
#              Date  Postcode             Regionname  Propertycount  Distance  \
# 63020  31/03/2018      3064  Northern Metropolitan           5833      20.6
# 63021  31/03/2018      3074  Northern Metropolitan           7955      15.3
# 63022  31/03/2018      3027   Western Metropolitan           1999      17.6
#
#                    CouncilArea
# 63020        Hume City Council
# 63021  Whittlesea City Council
# 63022     Wyndham City Council

# %%
print(ab.shape)
# Out:
# (63023, 13)

# %%
ab = ab.dropna()

# %%
print(ab.shape)
# Out:
# (48433, 13)

# %%
types = ab("Type")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-f3d561c79320> in <module>
# ----> 1 types = ab("Type")
#
# TypeError: 'DataFrame' object is not callable

# %%
types = ab["Type"]

# %%
rooms = ab["Rooms"]

# %%
price = list(ab["Price"])

# %%
import matplotlib.pyplot as plt
from matplotlib import colors

# %%
fig = plt.figure()
plt.hist(x = price,color = 'yellow',edgecolor = 'black',bins = 50)
plt.title("PRICES")
plt.xlabel("price range")
plt.ylabel("no.of houses")





plt.show()

# %%
reg = ab["Regionname"].value_counts()

# %%
reg = dict(reg)

# %%
print(reg)
a = reg.keys()
b = reg.values()
# Out:
# {'Northern Metropolitan': 13598, 'Southern Metropolitan': 12549, 'Western Metropolitan': 9680, 'Eastern Metropolitan': 7585, 'South-Eastern Metropolitan': 4010, 'Northern Victoria': 455, 'Eastern Victoria': 374, 'Western Victoria': 182}

# %%
fig = plt.figure(figsize = (5,5))
plt.pie(x = b,labels = a)

plt.show()

# %%
fig = plt.figure(figsize = (25,10))
plt.bar(height = b,x = a,color = 'red',edgecolor = 'blue')
plt.title("Bar Graph")
plt.show()

# %%
price = ab["Price"]
price = list(price)

dist = ab["Distance"]
dist = list(dist)

# %%
fig = plt.figure(figsize=(20,20))
plt.plot(dist,price,linestyle="",marker="o",color = 'red')
plt.show()
